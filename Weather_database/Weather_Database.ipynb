# %%
#import dependancies
import pandas as pd
import numpy as np
from datetime import datetime 
from citipy import citipy
import requests
#from config import weather_api_key

# %%
import sys 


from config import weather_api_key
api_key = weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/z_/73qqr3w53dl5wg1623jypxd40000gp/T/ipykernel_69882/1687618733.py in <module>
#       2
#       3
# ----> 4 from config import weather_api_key
#       5 api_key = weather_api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.000,high=90.000,size=2000)

lngs=np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.    
for i, city  in enumerate (cities):
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count +=1
        record_count +=1
        time.sleep(60) 
        # Create endpoint URL with each city.
    city_url = url + "&q=" +city.replace(" ", " +")
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        weather_description = city_weather["weather"][0]["description"]
       
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Country": city_country})
                          #"Date": city_date
                        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | najran
# Processing Record 2 of Set 1 | caravelas
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | togur
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | saint-joseph
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | meulaboh
# Processing Record 9 of Set 1 | coihaique
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 1 | bambous virieux
# City not found. Skipping...
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | waverly
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | sibolga
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | bilma
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | tura
# Processing Record 26 of Set 1 | dingle
# Processing Record 27 of Set 1 | kalmunai
# Processing Record 28 of Set 1 | broome
# Processing Record 29 of Set 1 | nuuk
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | mae hong son
# City not found. Skipping...
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | poco branco
# City not found. Skipping...
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | srandakan
# Processing Record 39 of Set 1 | clovis
# Processing Record 40 of Set 1 | manggar
# Processing Record 41 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 43 of Set 1 | zhumadian
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | iskele
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | ahuimanu
# Processing Record 49 of Set 1 | richards bay
# City not found. Skipping...
# Processing Record 50 of Set 1 | georgetown
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z_/73qqr3w53dl5wg1623jypxd40000gp/T/ipykernel_11772/3214531562.py in <module>
#      14         set_count +=1
#      15         record_count +=1
# ---> 16         time.sleep(60)
#      17         # Create endpoint URL with each city.
#      18     city_url = url + "&q=" +city.replace(" ", " +")
#
# NameError: name 'time' is not defined

# %%
#Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#Data is same as table shown in module challenge
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Najran  17.4924   44.1277     63.52        31           6
# 1     Caravelas -17.7125  -39.2481     85.91        68          97
# 2     Upernavik  72.7868  -56.1549      8.24        93         100
# 3         Togur  58.3631   82.8265     30.36        95         100
# 4     Hithadhoo  -0.6000   73.0833     82.11        74          25
# 5  Saint-Joseph -21.3667   55.6167     77.36        84          28
# 6       Ushuaia -54.8000  -68.3000     51.46        43          75
# 7      Meulaboh   4.1363   96.1285     78.24        84          99
# 8     Coihaique -45.5752  -72.0662     70.41        49          40
# 9      Khatanga  71.9667  102.5000     -4.85        80         100
#
#    Wind Speed Current Description Country
# 0        5.30           clear sky      SA
# 1       11.59     overcast clouds      BR
# 2        3.74     overcast clouds      GL
# 3       15.99          light snow      RU
# 4        5.39    scattered clouds      MV
# 5        8.48    scattered clouds      RE
# 6       35.68       broken clouds      AR
# 7        3.42     overcast clouds      ID
# 8       11.50    scattered clouds      CL
# 9       13.98     overcast clouds      RU

# %%
#Set Column Order as per the Module table
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Najran      SA  17.4924   44.1277     63.52        31           6
# 1     Caravelas      BR -17.7125  -39.2481     85.91        68          97
# 2     Upernavik      GL  72.7868  -56.1549      8.24        93         100
# 3         Togur      RU  58.3631   82.8265     30.36        95         100
# 4     Hithadhoo      MV  -0.6000   73.0833     82.11        74          25
# 5  Saint-Joseph      RE -21.3667   55.6167     77.36        84          28
# 6       Ushuaia      AR -54.8000  -68.3000     51.46        43          75
# 7      Meulaboh      ID   4.1363   96.1285     78.24        84          99
# 8     Coihaique      CL -45.5752  -72.0662     70.41        49          40
# 9      Khatanga      RU  71.9667  102.5000     -4.85        80         100
#
#    Wind Speed Current Description
# 0        5.30           clear sky
# 1       11.59     overcast clouds
# 2        3.74     overcast clouds
# 3       15.99          light snow
# 4        5.39    scattered clouds
# 5        8.48    scattered clouds
# 6       35.68       broken clouds
# 7        3.42     overcast clouds
# 8       11.50    scattered clouds
# 9       13.98     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_DataBase.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file,index_label="City_ID")
